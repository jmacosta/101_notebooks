# %% [markdown]
# # Ejercicio 6. Jerigonza
#
# ## Enunciado
#
# Jerigonza es una variante lúdica del español que consiste en añadir, en nuestro caso, la sílaba pi despues de cada vocal de una palabra en español.
#
# Construye un programa que pida una frase al usuario y que la transforme en jerigonza, imprimiéndola debajo.

# %% [markdown]
# ## Ayuda a la implementación
#
# Recuerda que una cadena funciona como una lista y puedes iterar sobre ella.

# %%
phrase = input("Introduzca frase ")
new_phrase = ''
for word in phrase:
    new_word = ''
    for character in word:
         if character in 'aeiouAEIOU':
             new_word += character+'pi'
         else: 
            new_word += character
    new_phrase =  new_phrase + new_word
print (new_phrase)
# Out:
# hopilapi qupiepi tapil
