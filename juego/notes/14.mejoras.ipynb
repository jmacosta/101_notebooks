# %% [markdown]
# # Mejoras
#
# -----------------------

# %% [markdown]
# ## Opcional
#
# Por tu cuenta, amplíalo a Rock, paper, scissors, lizzard, spock
#
# ![](http://geekandsundry.com/wp-content/uploads/2015/05/Rock-Paper-Scissors-Lizard-Spock.jpg)

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('_tsy4q9ibAE')

# %% [markdown]
# ## Obligatorio
#
# Nuestro software está bastante bien:
#
# * Aparentemente funciona (haría falta tests para certificarlo)
# * Gestiona los errores del dominio
# * Captura los posibles pánicos
# * Al ser una cutrez, no tenemos que preocuparnos por errores externos o de infraestructura.
#
# Sin embargo, hay algo que nos mordió el culo cuando menos lo esperábamos: los tipos.
#
# Hemos visto que el hecho de que Python no preste demasiada atención a los tipos de los parámetros de las funciones, ni al del valor de retorno puede ser un poco problemático.
#
# En la siguiente sección, veremos cómo subsanar eso.
